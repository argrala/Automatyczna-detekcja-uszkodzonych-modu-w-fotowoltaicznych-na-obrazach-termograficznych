# %% [markdown]
# Pobranie repozytorium i instalacja wymagan

# %%
# !pip3 install -U openmim
# !mim install mmcv-full
# !mim install mmdet
# !git clone https://github.com/open-mmlab/mmrotate.git
# %cd mmrotate
# !pip install -e .
# Out:
# Successfully installed colorama-0.4.6 commonmark-0.9.1 model-index-0.1.11 openmim-0.3.3 ordered-set-4.1.0 rich-12.6.0
# Successfully installed addict-2.4.0 mmcv-full-1.7.0 yapf-0.32.0
# Successfully installed mmdet-2.25.3 terminaltables-3.1.10
# Successfully installed e2cnn-0.2.2 mmrotate-0.3.3

# %% [markdown]
# Pobranie przetrenowanego modelu

# %%
# !mim download mmrotate --config oriented_rcnn_r50_fpn_1x_dota_le90 --dest .
# Out:
# /usr/local/lib/python3.7/dist-packages/mmcv/__init__.py:21: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   'On January 1, 2023, MMCV will release v2.0.0, in which it will remove '
# processing oriented_rcnn_r50_fpn_1x_dota_le90...
# downloading ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.1/158.1 MiB 39.3 MB/s eta 0:00:00
# Successfully downloaded oriented_rcnn_r50_fpn_1x_dota_le90-6d2b2ce0.pth to /content/mmrotate
# Successfully dumped oriented_rcnn_r50_fpn_1x_dota_le90.py to /content/mmrotate

# %% [markdown]
# Pobranie zbioru danych z dysku Google

# %%
from google.colab import drive
drive.mount('/content/drive')
# !apt install unzip
# !unzip "/content/drive/MyDrive/mmRotate_data_PV.zip" -d "/content/mmrotate"
# Out:
# Mounted at /content/drive
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# unzip is already the newest version (6.0-21ubuntu1.2).

# %% [markdown]
# Przypisanie klass do zbioru danych

# %%
from mmrotate.datasets.builder import ROTATED_DATASETS
from mmrotate.datasets.dota import DOTADataset
@ROTATED_DATASETS.register_module()
class PVDataset(DOTADataset):
    CLASSES = ('PV_module', 'DI', 'HS', 'TR', 'MH', 'REF')
# Out:
# /usr/local/lib/python3.7/dist-packages/mmcv/__init__.py:21: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   'On January 1, 2023, MMCV will release v2.0.0, in which it will remove '

# %% [markdown]
# Ustawienie zalecancyh nastaw dla architektury

# %%
from mmcv import Config
cfg = Config.fromfile('/content/mmrotate/configs/oriented_rcnn/oriented_rcnn_r50_fpn_1x_dota_le90.py')

# %% [markdown]
# Modyfikacja ustawien

# %%
from mmdet.apis import set_random_seed
cfg.dataset_type = 'PVDataset'
cfg.data_root = 'mmRotate_data_PV/'
cfg.data.test.type = 'PVDataset'
cfg.data.test.data_root = 'mmRotate_data_PV/'
cfg.data.test.ann_file = 'test'
cfg.data.test.img_prefix = 'images'
cfg.data.train.type = 'PVDataset'
cfg.data.train.data_root = 'mmRotate_data_PV/'
cfg.data.train.ann_file = 'train'
cfg.data.train.img_prefix = 'images'
cfg.data.val.type = 'PVDataset'
cfg.data.val.data_root = 'mmRotate_data_PV/'
cfg.data.val.ann_file = 'valid'
cfg.data.val.img_prefix = 'images'
cfg.model.roi_head.bbox_head.num_classes = 6
cfg.load_from = 'oriented_rcnn_r50_fpn_1x_dota_le90-6d2b2ce0.pth'
cfg.work_dir = './temp_exps'
cfg.lr_config.warmup = None
cfg.runner.max_epochs = 81
cfg.log_config.interval = 10
cfg.evaluation.metric = 'mAP'
cfg.evaluation.interval = 3
cfg.checkpoint_config.interval = 3
cfg.seed = 0
set_random_seed(0, deterministic=False)
cfg.gpu_ids = range(1)
cfg.device='cuda'
cfg.log_config.hooks = [
    dict(type='TextLoggerHook'),
    dict(type='TensorboardLoggerHook')]
print(f'Config:\n{cfg.pretty_text}')

# %% [markdown]
# Dodatkowa modyfikacja optymalizatora

# %%
cfg.optimizer_config = dict(_delete_=True, grad_clip=dict(max_norm=35, norm_type=2))
cfg.optimizer = dict(type='Adam', lr=0.0003, weight_decay=0.0001)
cfg.optimizer_config = dict(grad_clip=dict(max_norm=35, norm_type=2))

# %% [markdown]
# Uczenie sieci

# %%
import os.path as osp
import mmcv
from mmdet.datasets import build_dataset
from mmdet.models import build_detector
from mmdet.apis import train_detector
datasets = [build_dataset(cfg.data.train)]
model = build_detector(
    cfg.model, train_cfg=cfg.get('train_cfg'), test_cfg=cfg.get('test_cfg'))
model.CLASSES = datasets[0].CLASSES
mmcv.mkdir_or_exist(osp.abspath(cfg.work_dir))
train_detector(model, datasets, cfg, distributed=False, validate=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/mmdet/models/dense_heads/anchor_head.py:116: UserWarning: DeprecationWarning: `num_anchors` is deprecated, for consistency or also use `num_base_priors` instead
#   warnings.warn('DeprecationWarning: `num_anchors` is deprecated, '
# 2022-11-17 14:23:33,400 - mmdet - INFO - Automatic scaling of learning rate (LR) has been disabled.
# 2022-11-17 14:23:33,544 - mmdet - INFO - load checkpoint from local path: oriented_rcnn_r50_fpn_1x_dota_le90-6d2b2ce0.pth
# 2022-11-17 14:23:33,695 - mmdet - WARNING - The model and loaded state dict do not match exactly
#
# size mismatch for roi_head.bbox_head.fc_cls.weight: copying a param with shape torch.Size([16, 1024]) from checkpoint, the shape in current model is torch.Size([7, 1024]).
# size mismatch for roi_head.bbox_head.fc_cls.bias: copying a param with shape torch.Size([16]) from checkpoint, the shape in current model is torch.Size([7]).
# 2022-11-17 14:23:33,701 - mmdet - INFO - Start running, host: root@598624092a77, work_dir: /content/mmrotate/temp_exps
# 2022-11-17 14:23:33,703 - mmdet - INFO - Hooks will be executed in the following order:

# %% [markdown]
# Prezentacja wyników detekcji

# %%
from mmdet.apis import inference_detector, show_result_pyplot
img = mmcv.imread('mmRotate_data_PV/images/DJI_1_MK (388).png')
model.cfg = cfg
result = inference_detector(model, img)
show_result_pyplot(model, img, result, score_thr=0.3)
